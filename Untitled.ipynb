# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame
from pandas.tools.plotting import scatter_matrix

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8, 6
sb.set_style('whitegrid')

# %%
address1 = 'C:\Users\harsh\Desktop\SEM182\ANTH412\labs\lab04-datause-ores.csv'
ores = pd.read_csv(address1)
ores
# Out:
#        Sample no.   Country                                Location  Ref.  \
# 0       Kambia 1a    Cyprus                                  Kambia    38
# 1       Kambia 1b    Cyprus                                  Kambia    38
# 2       Kambia 3a    Cyprus                                  Kambia    38
# 3         Limni a    Cyprus                                   Limni    38
# 4         Limni b    Cyprus                                   Limni    38
# 5      Mathiati a    Cyprus                                Mathiati    38
# 6      Mathiati b    Cyprus                                Mathiati    38
# 7    Peristerka a    Cyprus                              Peristerka    38
# 8    Peristerka b    Cyprus                              Peristerka    38
# 9     Pitharokoma    Cyprus                             Pitharokoma    38
# 10            NaN    Cyprus                            Skouriotissa     6
# 11           EVL2    Cyprus                   Limni axis, Evloymeni    64
# ...

# %%
#ores_df = pd.DataFrame(ores.ix[:, (6, 7, 8)].values, columns = ['208Pb/206Pb', '207Pb/206Pb', '206Pb/204Pb', '207Pb/204Pb', '208Pb/204Pb'])
sb.pairplot(ores, hue='Country', palette='hls')

# %%
# Out:
#    Catalog No. Country         Description Workshop  Period  208Pb/206Pb  \
# 0       ATL599     Unk            figurine       A1       1        2.049
# 1       ATL648     Unk        oxhide ingot       A1       1        2.078
# 2       ATL693     Unk            figurine       A1       1        2.057
# 3       ATL734     Unk     bangle fragment       A1       1        2.090
# 4       ATL771     Unk  socketed spearhead       A1       1        2.053
# 5       ATL797     Unk          small bead       A1       1        2.092
# 6       ATL869     Unk     bangle fragment       A1       1        2.123
# 7       ATL985     Unk     bangle fragment       A1       1        2.119
# 8       ATL345     Unk        oxhide ingot       B2       1        2.066
# 9       ATL360     Unk  socketed spearhead       B2       1        2.075
# 10      ATL366     Unk            figurine       B2       1        2.071
# 11      ATL398     Unk        oxhide ingot       B2       1        2.056
# ...

# %%
country = ores.values[:, 1]
Sardinia = pd.DataFrame(ores.loc[ores['Country']=='Sardinia', :])
Cyprus =  pd.DataFrame(ores.loc[ores['Country']=='Cyprus', :])
Greece =  pd.DataFrame(ores.loc[ores['Country']=='Greece', :])

fig = plt.figure()

# %%
#208Pb/206Pb
#207Pb/206Pb
#7, 8, 9


# only 206 ~ 206Pb/204Pb
# only 207 ~ 207Pb/204Pb
# only 208 ~ 208Pb/204Pb

#cars_df = pd.DataFrame((cars.ix[:, (1, 3, 4, 6)].values), columns = ['mpg', 'disp', 'hp', 'wt'])
#cars_target = cars.ix[:, 9].values
#target_names = [0, 1]
#
#cars_df['group'] = pd.Series(cars_target, dtype = 'category')
#sb.pairplot(cars_df, hue='group', palette='hls')


#fig = plt.figure(1)
#plt = fig.add_axes([.1, .1, 1, 1])

#ax.scatter(ores[:, 7], ores[:, 8], data)

#ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', style='scatter', hue='Country', palette='hls')

cmap = {'Cyprus' : 'blue', 'Sardinia' : 'red', 'Greece' : 'yellow'}
ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])

# %%
ores.plot(x='208Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])

# %%
ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])

# %%
ores.plot(x='208Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = plt.axes( projection='3d')

#cars_df = pd.DataFrame((cars.ix[:, (1, 3, 4, 6)].values), columns = ['mpg', 'disp', 'hp', 'wt'])

X = Sardinia['206Pb/204Pb']
Y = Sardinia['207Pb/204Pb']
Z_df = pd.DataFrame((artifacts.iloc[:, 7:9].values))

Z_dft = Z_df

Z = 

len(Z_dft.columns)
# Out:
# 2

# %%
#ax.plot_wireframe(X, Y, Z_dft, rstride=1, cstride=1,
 #               cmap='cubehelix', edgecolor='none')
ax.plot_trisurf(X, Y, Z_dft, cmap=plt.cm.viridis, linewidth=0.2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-172-9135e64c1395> in <module>()
#       1 #ax.plot_wireframe(X, Y, Z_dft, rstride=1, cstride=1,
#       2  #               cmap='cubehelix', edgecolor='none')
# ----> 3 ax.plot_trisurf(X, Y, Z_dft, cmap=plt.cm.viridis, linewidth=0.2)
#
# C:\Users\harsh\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in plot_trisurf(self, *args, **kwargs)
#    2001         xt = tri.x[triangles]
#    2002         yt = tri.y[triangles]
# -> 2003         zt = z[triangles]
#    2004
#    2005         # verts = np.stack((xt, yt, zt), axis=-1)
#
# IndexError: index 115 is out of bounds for axis 0 with size 60

# %%
pd1 = pd.DataFrame(artifacts.loc[artifacts['Period'] == 1])
pd2 = pd.DataFrame(artifacts.loc[artifacts['Period'] == 2])

jp = sb.jointplot(x='208Pb/204Pb', y='207Pb/204Pb', data=ores,
                   kind='reg', space=0, size=5, ratio=4)
# Out:
# C:\Users\harsh\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\harsh\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
address2 = 'C:\Users\harsh\Desktop\SEM182\ANTH412\labs\lab04-datause-artifacts.csv'
artifacts = pd.read_csv(address2)

ratio208 = artifacts['208Pb/206Pb'] * artifacts['206Pb/204Pb']

artifacts['208Pb/204Pb'] = ratio208

artifacts
# Out:
#    Catalog No. Country         Description Workshop  Period  208Pb/206Pb  \
# 0       ATL599     Unk            figurine       A1       1        2.049
# 1       ATL648     Unk        oxhide ingot       A1       1        2.078
# 2       ATL693     Unk            figurine       A1       1        2.057
# 3       ATL734     Unk     bangle fragment       A1       1        2.090
# 4       ATL771     Unk  socketed spearhead       A1       1        2.053
# 5       ATL797     Unk          small bead       A1       1        2.092
# 6       ATL869     Unk     bangle fragment       A1       1        2.123
# 7       ATL985     Unk     bangle fragment       A1       1        2.119
# 8       ATL345     Unk        oxhide ingot       B2       1        2.066
# 9       ATL360     Unk  socketed spearhead       B2       1        2.075
# 10      ATL366     Unk            figurine       B2       1        2.071
# 11      ATL398     Unk        oxhide ingot       B2       1        2.056
# ...

# %%
sb.scatterplot()
