# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame
from pandas.tools.plotting import scatter_matrix

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %matplotlib inline
rcParams['figure.figsize'] = 10, 6
sb.set_style('whitegrid')

# %%
address1 = 'C:\Users\harsh\Desktop\SEM182\ANTH412\labs\lab04-datause-ores.csv'
ores = pd.read_csv(address1)
address2 = 'C:\Users\harsh\Desktop\SEM182\ANTH412\labs\lab04-datause-artifacts.csv'
artifacts = pd.read_csv(address2)

#adding ratio column for artifacts data frame
ratio208 = artifacts['208Pb/206Pb'] * artifacts['206Pb/204Pb']
artifacts['208Pb/204Pb'] = ratio208

artifacts
# Out:
#    Catalog No. Country         Description Workshop  Period  208Pb/206Pb  \
# 0       ATL599     Unk            figurine       A1       1        2.049
# 1       ATL648     Unk        oxhide ingot       A1       1        2.078
# 2       ATL693     Unk            figurine       A1       1        2.057
# 3       ATL734     Unk     bangle fragment       A1       1        2.090
# 4       ATL771     Unk  socketed spearhead       A1       1        2.053
# 5       ATL797     Unk          small bead       A1       1        2.092
# 6       ATL869     Unk     bangle fragment       A1       1        2.123
# 7       ATL985     Unk     bangle fragment       A1       1        2.119
# 8       ATL345     Unk        oxhide ingot       B2       1        2.066
# 9       ATL360     Unk  socketed spearhead       B2       1        2.075
# 10      ATL366     Unk            figurine       B2       1        2.071
# 11      ATL398     Unk        oxhide ingot       B2       1        2.056
# ...

# %%
rcParams['figure.figsize'] = 8, 6
cmap = {'Cyprus' : 'darkblue', 'Sardinia' : 'brown', 'Greece' : 'purple'}
ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
countries = set(ores['Country'])

#fig, ax = plt.subplots()
#for g in np.unique(countries):
#    ix = np.where(countries == g)
#    ax.scatter(ores[ix], ores[ix], c = cmap[g], label = g, s = 100)

ores.plot(x='208Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
ores.plot(x='208Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])

# %%
import pandas as pd
artifactsP1 = pd.DataFrame(artifacts.loc[artifacts['Period']==1, :])
artifactsP2 = pd.DataFrame(artifacts.loc[artifacts['Period']==2, :])

a1p1 = pd.DataFrame(artifactsP1.loc[artifactsP1['Workshop']=='A1', :])
b2p1 = pd.DataFrame(artifactsP1.loc[artifactsP1['Workshop']=='B2', :])
c4p1 = pd.DataFrame(artifactsP1.loc[artifactsP1['Workshop']=='C4', :])

a1p2 = pd.DataFrame(artifactsP2.loc[artifactsP2['Workshop']=='A1', :])
b2p2 = pd.DataFrame(artifactsP2.loc[artifactsP2['Workshop']=='B2', :])
c4p2 = pd.DataFrame(artifactsP2.loc[artifactsP2['Workshop']=='C4', :])

ws1 = pd.DataFrame(artifacts.loc[artifacts['Workshop']=='A1', :])
ws2 = pd.DataFrame(artifacts.loc[artifacts['Workshop']=='B2', :])
ws3 = pd.DataFrame(artifacts.loc[artifacts['Workshop']=='C4', :])

periodMap = {1: 'lightblue', 2 : 'brown'}
workshopMap = {'A1': 'yellow', 'B2': 'orange', 'C4': 'red'}
rcParams['figure.figsize'] = 8, 6

#artifacts.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c)
artifacts.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[periodMap.get(c, 'black') for c in artifacts.Period])
artifacts.plot(x='208Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[periodMap.get(c, 'black') for c in artifacts.Period])

print artifacts.groupby('Period').mean()
# Out:
#         208Pb/206Pb  207Pb/206Pb  206Pb/204Pb  207Pb/204Pb  208/206-err  \
# Period
# 1          2.085033     0.843567    18.568200    15.658600     0.002093
# 2          2.082033     0.845967    18.498467    15.641933     0.002090
#
#         207/206-err  206/204-err  207/204-err  208Pb/204Pb
# Period
# 1          0.000830     0.018577     0.015670    38.708873
# 2          0.000833     0.018500     0.015647    38.507606

# %%
#figure, axs = plt.subplots(1,2)
rcParams['figure.figsize'] = 8, 6


#artifacts.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[workshopMap.get(c, 'black') for c in artifacts.Workshop])
ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
artifacts.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[workshopMap.get(c, 'black') for c in artifacts.Workshop])

# %%
rcParams['figure.figsize'] = 8, 6

ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
artifactsP1.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[periodMap.get(c, 'black') for c in artifacts.Period])

# %%
#between workshops 
#ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
artifactsP1.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[periodMap.get(c, 'black') for c in artifacts.Period])

# %%
#between time periods

# %%
#workshops between time periods

#A1 in period 1 and period 2
ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
ws1.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[periodMap.get(c, 'black') for c in ws1.Period])

#B2 in period 1 and period 2
ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
ws2.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[periodMap.get(c, 'black') for c in ws2.Period])

ax = ores.plot(x='206Pb/204Pb', y='207Pb/204Pb', kind='scatter', c=[cmap.get(c, 'black') for c in ores.Country])
ws3.plot(x='206Pb/204Pb', y='207Pb/204Pb', s=100, ax=ax, edgecolor='black', kind='scatter', c=[periodMap.get(c, 'black') for c in ws3.Period])

# %%
ws3
# Out:
#    Catalog No. Country         Description Workshop  Period  208Pb/206Pb  \
# 20      ATL323     Unk          small bead       C4       1        2.083
# 21      ATL336     Unk        oxhide ingot       C4       1        2.049
# 22      ATL393     Unk            figurine       C4       1        2.082
# 23      ATL522     Unk            figurine       C4       1        2.072
# 24      ATL535     Unk        oxhide ingot       C4       1        2.091
# 25      ATL545     Unk        oxhide ingot       C4       1        2.086
# 26      ATL669     Unk                slag       C4       1        2.074
# 27      ATL747     Unk  socketed spearhead       C4       1        2.104
# 28      ATL888     Unk                slag       C4       1        2.117
# 29      ATL893     Unk     bangle fragment       C4       1        2.109
# 50     ATL1141     Unk  socketed spearhead       C4       2        2.107
# 51     ATL1222     Unk        oxhide ingot       C4       2        2.105
# ...

# %%
ws1
# Out:
#    Catalog No. Country         Description Workshop  Period  208Pb/206Pb  \
# 0       ATL599     Unk            figurine       A1       1        2.049
# 1       ATL648     Unk        oxhide ingot       A1       1        2.078
# 2       ATL693     Unk            figurine       A1       1        2.057
# 3       ATL734     Unk     bangle fragment       A1       1        2.090
# 4       ATL771     Unk  socketed spearhead       A1       1        2.053
# 5       ATL797     Unk          small bead       A1       1        2.092
# 6       ATL869     Unk     bangle fragment       A1       1        2.123
# 7       ATL985     Unk     bangle fragment       A1       1        2.119
# 30     ATL1052     Unk          small bead       A1       2        2.047
# 31     ATL1093     Unk            figurine       A1       2        2.069
# 32      ATL111     Unk                slag       A1       2        2.056
# 33     ATL1142     Unk            figurine       A1       2        2.066
# ...
